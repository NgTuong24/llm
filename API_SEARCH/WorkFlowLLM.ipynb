# %%
# !pip install langchain-community
# !pip install -U duckduckgo-search
# !pip install langchain
# !pip install langchain_google_genai
# !pip install "unstructured[pdf]"
# !pip install chromadb

# %%
import os
import google.generativeai as genai

os.environ['GOOGLE_API_KEY'] = 'AIzaSyAk2SGsbPm5H-6K-rNgnIhQsBYwkm2GHhE'
genai.configure(api_key='AIzaSyAk2SGsbPm5H-6K-rNgnIhQsBYwkm2GHhE')

# %% [markdown]
# # DATA

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.schema.document import Document
from langchain.vectorstores.chroma import Chroma
from langchain_google_genai import GoogleGenerativeAIEmbeddings

DATA_PATH = r"/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf"
CHROMA_PATH = "./Chroma_finance"

def load_documents():
    # document_loader = PyPDFDirectoryLoader(DATA_PATH)
    # return document_loader.load()
    # from langchain_community.document_loaders import PyPDFLoader
    # loader = PyPDFLoader(DATA_PATH)
    # pages = loader.load_and_split()
    # return pages
    from langchain_community.document_loaders import UnstructuredFileLoader
    loader = UnstructuredFileLoader(DATA_PATH)
    docs = loader.load()
    return docs


def split_documents(documents: list[Document]):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=800,
        chunk_overlap=80,
        length_function=len,
        is_separator_regex=False,
    )
    return text_splitter.split_documents(documents)


def get_embedding_function():
    gemini_embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")
    return gemini_embeddings


def add_to_chroma(chunks: list[Document]):
    db = Chroma(
        persist_directory=CHROMA_PATH, embedding_function=get_embedding_function()
    )

    # Calculate Page IDs.
    chunks_with_ids = calculate_chunk_ids(chunks)

    # Add or Update the documents.
    existing_items = db.get(include=[])  # IDs are always included by default
    existing_ids = set(existing_items["ids"])
    print(f"Number of existing documents in DB: {len(existing_ids)}")

    new_chunks = []
    for chunk in chunks_with_ids:
        if chunk.metadata["id"] not in existing_ids:
            new_chunks.append(chunk)

    if len(new_chunks):
        print(f"👉 Adding new documents: {len(new_chunks)}")
        new_chunk_ids = [chunk.metadata["id"] for chunk in new_chunks]
        db.add_documents(new_chunks, ids=new_chunk_ids)
        db.persist()
    else:
        print("✅ No new documents to add")


def calculate_chunk_ids(chunks):
    last_page_id = None
    current_chunk_index = 0

    for chunk in chunks:
        source = chunk.metadata.get("source")
        page = chunk.metadata.get("page")
        current_page_id = f"{source}:{page}"
        if current_page_id == last_page_id:
            current_chunk_index += 1
        else:
            current_chunk_index = 0
        chunk_id = f"{current_page_id}:{current_chunk_index}"
        last_page_id = current_page_id
        chunk.metadata["id"] = chunk_id

    return chunks

# %%
documents = load_documents()
chunks = split_documents(documents)
add_to_chroma(chunks)
# Out:
# Number of existing documents in DB: 0
# 👉 Adding new documents: 109
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   warn_deprecated(

# %% [markdown]
# #RUN

# %%
from langchain.load import dumps, loads
from langchain_community.utilities import DuckDuckGoSearchAPIWrapper
from langchain_community.tools import DuckDuckGoSearchResults
from langchain_core.documents import Document
from typing import List
wrapper = DuckDuckGoSearchAPIWrapper(max_results=10)
search = DuckDuckGoSearchResults(api_wrapper=wrapper, source="news")

def search_api(queries: list):
    res = []
    for query in queries:
        if query != "":
            res.append(search.run(query))
    return res

def format_sources(docs: str):
    key = ['snippet:', 'title:', 'link:']
    docs = docs[1:-1]
    list_doc = docs.split("],")
    source = []
    for doc in list_doc:
        metadata = {}
        ind_1 = doc.find(key[0])
        ind_2 = doc.find(key[1])
        ind_3 = doc.find(key[2])
        metadata['title'] = doc[ind_2 + 7:ind_3]
        metadata['source'] = doc[ind_3 + 6:]
        document = Document(
            page_content = doc[ind_1+2 + 7:ind_2],
            metadata=metadata
        )
        source.append(document)
    return source

def get_unique_union(documents: list[list]):
    """ Unique union of retrieved docs """
    # Flatten list of lists, and convert each Document to string
    # làm phằng, đưa list of list -> 1 list
    flattened_docs = [dumps(doc) for sublist in documents for doc in sublist]
    # Get unique documents
    unique_docs = list(set(flattened_docs))
    # Return list documents
    return [loads(doc) for doc in unique_docs]

# generate_queries = (
#     prompt_1
#     | model
#     | StrOutputParser()
#     | (lambda x: x.split("\n"))
#     )

def format_docs(docs: List[Document]) -> str:
    """Convert Documents to a single string.:"""
    formatted = [
        f"Article Snippet: {doc.page_content}" for doc in docs
    ]
    return "\n\n" + "\n\n".join(formatted)


def retrieval_local(generate_queries_chain, retrieval, question):
    print("retrieval_local")
    retrieval_chain = generate_queries_chain | retrieval.map() | get_unique_union
    docs = retrieval_chain.invoke({"question":question})
    return docs

def retrieval_onl(generate_queries_chain, question):
    print("retrieval_onl")
    search_chain = generate_queries_chain | search_api
    docs_search = search_chain.invoke({"question":question})
    documents = []
    for val in docs_search.copy():
        doc = format_sources(val)
        documents.extend(doc)
    return documents

def retrieval_fusion(generate_queries_chain, retrieval, question):
    print("retrieval")
    doc_pdf = retrieval_local(generate_queries_chain, retrieval, question)
    doc_search = retrieval_onl(generate_queries_chain, question)
    return doc_pdf + doc_search

# %%
from langchain_google_genai import GoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import PromptTemplate
from operator import itemgetter
from langchain_core.runnables import (
    RunnableLambda,
    RunnableParallel,
    RunnablePassthrough,
)

model = GoogleGenerativeAI(model="models/gemini-1.5-pro-001", temperature=0.1)
embeddings = get_embedding_function()
db = Chroma(persist_directory=CHROMA_PATH, embedding_function=embeddings)
retrieval = db.as_retriever(search_kwargs={"k": 1})

# %%
template="""You are an AI language model assistant, question analysis expert. Your task is to base on user questions point out important headings
with the intention of asking questions about each heading. By creating many small questions, your goal
is to help make the answer clearer on each relevant aspect.
Provide these headers separated by newlines: \n
Question: {question}"""

template2 = """Answer the following question based on this context:
{context}
Question: {question}
"""

template4 = """
You're a helpful AI assistant. Given a user question and some DuckDuckGoSearchResults article snippets,
answer the user question. If none of the articles answer the question, just say you don't know."
\n\nHere are the context:{context}
"""

prompt_1 = PromptTemplate.from_template(template)
prompt_2 = PromptTemplate.from_template(template2)
# prompt_3 = PromptTemplate.from_template(template3)
prompt_4 = PromptTemplate.from_template(template4)

# %%
question = "What are the determinants of financial inclusion in Vietnam?"
generate_queries = (
    prompt_1
    | model
    | StrOutputParser()
    | (lambda x: x.split("\n"))
)
generate_queries.invoke(question)
# context = retrieval_fusion(generate_queries, retrieval, question)
# Out:
# ['## Determinants of Financial Inclusion in Vietnam:',
#  '',
#  '1. **Economic Factors:**',
#  '    * What is the role of GDP growth in promoting financial inclusion?',
#  '    * How does income inequality impact access to financial services?',
#  '    * What is the impact of employment levels and types of employment on financial inclusion?',
#  '',
#  '2. **Demographic Factors:**',
#  '    * How does age influence financial inclusion rates?',
#  '    * Are there gender disparities in access to financial services?',
#  '    * Does education level correlate with financial inclusion?',
#  '    * What is the impact of geographical location (urban vs. rural) on financial access?',
#  '',
#  '3. **Institutional Factors:**',
#  '    * What is the role of government policies and regulations in promoting financial inclusion?',
#  '    * How developed is the financial infrastructure (e.g., bank branches, ATMs) in Vietnam?',
#  '    * What is the role of technology and digital financial services in expanding financial inclusion?',
#  '',
#  '4. **Cultural and Social Factors:**',
#  '    * What are the prevailing attitudes and perceptions towards formal financial services?',
#  '    * How does financial literacy impact the use of financial products and services?',
#  '    * Are there any cultural or social norms that act as barriers to financial inclusion?',
#  '',
#  '5. **Supply-Side Factors:**',
#  '    * What are the challenges faced by financial institutions in reaching underserved populations?',
#  '    * Are financial products and services designed to meet the needs of diverse customer segments?',
#  '    * How affordable are financial services for low-income individuals and businesses? ',
#  '']

# %%
context = retrieval_fusion(generate_queries, retrieval, question)
context
# Out:
# retrieval
# retrieval_local
# retrieval_onl
# [Document(page_content='Financial inclusion is mainly observed on the suppli- ers’ side while the demand side which presents the actual usage of financial products or services more accurately reflects the level of financial inclusion of end-consumers. On the supply side, access to financial institutions is usu- the numbers of bank ally reported as the data of branches and automatic teller machines (ATM). These indicators considered banking penetration two common measurements of financial inclusion (Beck et al., 2005, Beck et al., 2008). Sarma (2008) also employs the pro- portion of loans and deposits to GDP as the result of', metadata={'id': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf:None:5', 'source': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf'}),
#  Document(page_content='From the user’s characteristics, a huge number of studies empirically assess the potential key driver. As a pioneer, Demirg€ucx-Kunt and Klapper (2012) combine the Global Financial Inclusion database with their quali- tative research in order to explore the vital role of per- sonal features in determining their financial inclusion. Their research covers 148 countries and is considered the core research on this topic. Accordingly, Allen et al. (2012) documented that both characteristics related to income and resident area are two main concerns for financial inclusion. In particular, the poor people who live in rural areas tend to be excluded from financial products and services. Additionally, transaction costs and distance to financial service counters are also crucial barriers to', metadata={'id': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf:None:31', 'source': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf'}),
#  Document(page_content='mobility or migration overseas of men (United Nations Capital Development Fund, 2006). The level of financial inclusion of women is also emphasized in a range of research of Allen et al. (2012), Akudugu (2013).', metadata={'id': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf:None:59', 'source': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf'}),
#  Document(page_content='1.397* (0.282) 1.064** (0.034) 0.999*** (0.000)\n\n1.173 (0.311) 1.098** (0.047) 0.999*** (0.001)\n\n.1874 1,002\n\n.0507 1,002\n\ndemographic remain unchanged in their dimension and significant correla- tion with financial inclusion.\n\ncharacteristics\n\nrelatively\n\nConclusion', metadata={'id': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf:None:90', 'source': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf'}),
#  Document(page_content='to formal finan- cial goods and services thanks to financial inclusion, which has been a prominent policy priority in many countries, particularly in developing and emerging economies (Allen et al., 2016). Many governments are exerting great effort to ensure their citizens have access to a wide range of financial services and they have achieved financial inclusion, including India, Rwanda, and Kenya (Hove & Dubus, 2019; Nimbrayan et al., 2018; Otioma et al., 2019).', metadata={'id': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf:None:21', 'source': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf'}),
#  Document(page_content='Besides, borrowing is more dependent on age, educa- tion, income, and gender. However, due to the shortage in little evidence is found at the the strand of studies, national level. Akudugu (2013) employs data from 1,000 adults in Ghana and finds that 40% of respondents have been included in the formal financial sector. Demographic characteristics such as age, literacy, and income prove their significant role in determining financial inclusion. In addition, the author also explains that the distance from financial institutions, lack of information, lack of trust, and peer effects are the main reasons for financial exclu- sion in Ghana. Based on a micro-data survey conducted in Peru, Ca´ mara and Tuesta (2014) believed that women, rural residents, and people at a young age have a lower', metadata={'id': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf:None:34', 'source': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf'}),
#  Document(page_content='Additionally,\n\ninstitutions,\n\nself-inclusiveness\n\nin\n\nthe\n\nfinancial\n\nDeclaration of Conflicting Interests\n\nThe author(s) declared no potential conflicts of interest with respect to the research, authorship, and/or publication of this article.\n\nFunding\n\nThe author(s) received no financial support for the research, authorship, and/or publication of this article.\n\nORCID iD\n\nThi Anh Nhu Nguyen 4655\n\nhttps://orcid.org/0000-0003-3619-\n\nReferences\n\nAbel, S., Mutandwa, L., & Roux, P. (2018). A review of deter- minants of financial inclusion. International Journal of Eco- nomics and Financial Issues, 8(3), 1–8.', metadata={'id': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf:None:99', 'source': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf'}),
#  Document(page_content='International Monetary Fund. (2018). Financial Asia-pacific. International Monetary Fund\n\ninclusion in\n\nLeyshon, A., & Thrift, N. (1995). States geographies of finan- cial exclusion: Financial abandonment in Britain and the United States. Transactions of the Institute of British Geo- graphers, 20(3), 312–341.\n\nLusardi, A., & Tufano, P. (2015). Debt literacy, financial experiences, and overindebtedness. Journal of Pension\n\nSAGE Open\n\nEconomics and Finance, 14(4), 332–368. https://doi.org/10. 1017/s1474747215000232.\n\nNimbrayan, P. K., Tanwar, N., & Tripathi, R. K. (2018). Prad- han Mantri Jan Dhan Yojana (PMJDY): The biggest finan- cial inclusion initiative in the world. Economic Affairs, 63(2), 583–590. https://doi.org/10.30954/0424-2513.2.2018.38', metadata={'id': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf:None:105', 'source': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf'}),
#  Document(page_content='Furthermore, Burgess and Pande (2005) discovered that an increase in the number of bank accounts leads to the expansion of saving and lending activities in rural areas, which pushes the increase in overall production in non-agricultural sec- tors. Hence, it increases employment rate and reduces poverty in these communities.', metadata={'id': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf:None:23', 'source': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf'}),
#  Document(page_content='In this section, the authors aim to investigate individuals’ characteristics exclusion. Respondents have seven suggestions to answer why they do not have an account at a bank or other types of for- mal financial institutions. In terms of objective reasons, two aspects of the financial system are (1) financial insti- tutions are too far away and (2) financial services are too expensive. From the passive factors, respondents do not have the necessary documentation (identity card and wage slip) or do not have enough money to use financial institutions. In the subjective explanation, individuals do not trust financial institutions, do not have demands for financial services at a formal institution, or someone else in the family already has an account. Besides, religious reasons are also', metadata={'id': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf:None:70', 'source': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf'}),
#  Document(page_content='represents individuals’ labor force status with a value of 1 if individuals are in the workforce and 0 otherwise.', metadata={'id': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf:None:50', 'source': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf'}),
#  Document(page_content='to explain their\n\nfinancial\n\nSAGE Open\n\nTable 3. Financial Inclusion and Income.\n\nVariables\n\nHigh income group\n\nMiddle- and low-income group\n\nGender (male as reference)\n\nFemale\n\n0.097 (0.098)\n\n0.101 (0.071)\n\nEducation level (primary or less as reference)\n\nSecondary Tertiary or higher\n\n0.515*** (0.105) 1.019*** (0.134)\n\n0.289*** (0.076) 0.884*** (0.154)\n\nLabor force participation (out of labor force as reference)\n\nIn the work force\n\nAge Age2 R2 No. of observations\n\n20.014 (0.113) 0.026 (0.016) 20.001** (0.000) .1432 457\n\n0.205*** (0.077) 0.006 (0.011) 20.000 (0.000)\n\n.123 545\n\nSource. Authors’ calculation Note. All models refer to OLS regressions with robust standard errors. *p\\.1. **p\\.05. ***p\\.01.', metadata={'id': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf:None:72', 'source': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf'}),
#  Document(page_content=') 1 2 0 0 (\n\n.\n\n3 1 0 0 2\n\n.\n\n) 0 3 0 0 (\n\n.\n\n* 3 6 0 0 2 .\n\n) 1 3 0 0 (\n\n.\n\n* * 4 4 1 0 2 .\n\n) 9 2 0 0 (\n\n.\n\n9 4 0 0 2 .\n\nh t r o F\n\n) 7 4 0 0 (\n\n.\n\n9 2 0 0 2\n\n.\n\n) 6 3 0 0 (\n\n.\n\n* 1 7 0 0 .\n\n) 6 4 0 0 (\n\n.\n\n* * 8 3 2 0 2 .\n\n) 5 2 0 0 (\n\n.\n\n5 3 0 0\n\n.\n\n) 3 0 0 (\n\n.\n\n* * 5 8 0 0 2 .\n\n) 3 3 0 0 (\n\n.\n\n* * 4 3 1 0 2 .\n\n) 9 2 0 0 (\n\n.\n\n7 4 0 0 2 .\n\nt s e h c R\n\ni\n\n) 6 3 0 0 (\n\n.\n\n* 3 8 0 0 .\n\n) 1 3 0 0 (\n\n.\n\n* 4 6 0 0 2 .\n\n) 7 3 0 0 (\n\n.\n\n2 2 0 0\n\n.\n\n) 9 1 0 0 (\n\n.\n\n1 1 0 0 2\n\n.\n\n) 3 2 0 0 (\n\n.\n\n5 1 0 0\n\n.\n\n) 2 2 0 0 (\n\n.\n\n1 1 0 0\n\n.\n\n) 3 1 1 0 (\n\n.\n\n4 1 0 0 2\n\n.\n\nn o i t a p c i t r a p\n\ni\n\ne c r o\n\nf\n\nr o b a L\n\n) 5 0 0 0 (\n\n.\n\n) 0 0 0 0 (\n\n.\n\n8 0 0 0 2\n\n.\n\n* 0 0 0 0 .\n\n6 9 4 0\n\n.\n\n) 4 0 0 0 (\n\n.\n\n) 0 0 0 0 (\n\n.\n\n2 0 0 0\n\n.\n\n0 0 0 0\n\n.\n\n7 6 2 0\n\n.\n\n) 5 0 0 0 (\n\n.\n\n) 0 0 0 0 (\n\n.\n\n4 0 0 0', metadata={'id': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf:None:78', 'source': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf'}),
#  Document(page_content='Determinants of Financial Inclusion\n\nTable 2 clarifies the effect of individuals’ characteristics on the level of financial inclusion in Vietnam presented by the financial inclusion index. Generally, all of the characteristics in this model have a significant statistic\n\nM\n\nSD\n\nMinimum\n\nMaximum\n\n1.31 1.34\n\n1.36 1.40\n\n0 0\n\n6 6\n\n0.78 1.42 2.32\n\n0.99 1.41 1.49\n\n0 0 0\n\n6 6 6\n\n0.76 1.13 1.21 1.40 1.89\n\n0.95 1.27 1.29 1.43 1.53\n\n0 0 0 0 0\n\n4 6 6 6 6\n\n0.95 1.45\n\n1.12 1.44\n\n0 0\n\n6 6\n\n1.44 1.76 1.41 1.06 1.04 1.08 0.59 1.33\n\n1.49 1.60 1.36 1.25 0.91 1.13 0.85 1.38\n\n0 0 0 0 0 0 0 0\n\n6 6 6 6 4 6 3 6\n\nNguyen and Luong\n\nTable 2. Determinants of Financial Inclusion Scores.\n\nVariables\n\nZ-score (1)\n\nZ-score (2)\n\nGender (Male as reference)\n\nFemale\n\n0.105* (0.059)\n\n0.100* (0.059)', metadata={'id': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf:None:55', 'source': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf'}),
#  Document(page_content='robust and stable baseline results. Accordingly, these findings contribute to issuing adequate policies that break the barriers to financial inclusion and enhance financial inclusion, especially for less educated, poor, out of the workforce, and old people.', metadata={'id': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf:None:3', 'source': '/content/determinants-of-financial-inclusion-in-vietnam-a-demand-side-approach.pdf'}),
#  Document(page_content='The primary target of this paper is to measure an overall financial inclusion index by employing micro data of 1,002 respondents in Vietnam from the World Bank. Additionally, based on the calculation of financial inclusion index, we investigate the determinants of financial inclusion and examine the barriers to financial inclusion in Vietnam., ', metadata={'title': 'The Determinants of Financial Inclusion in Vietnam: A Demand-Side ..., ', 'source': 'https://journals.sagepub.com/doi/10.1177/21582440231210639'}),
#  Document(page_content='First, we construct an index of financial inclusion at the household level in Vietnam. Second, we identify the determinants of financial inclusion at the household level in the Vietnamese context. Vietnam is an emerging nation aiming to reduce poverty and inequality by promoting financial inclusion [ 6, 7 ]., ', metadata={'title': 'The determinants of financial inclusion from the households ..., ', 'source': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10473509/'}),
#  Document(page_content='We also identify the determinants of financial inclusion from the perspective of Vietnamese households. Our study also utilizes an ordered logit model to examine the effects of the determinants on each level of financial inclusion. Our empirical results reveal three key determinants, including (i) total income per household, (ii) relative ..., ', metadata={'title': 'The determinants of financial inclusion from the households ..., ', 'source': 'https://pubmed.ncbi.nlm.nih.gov/37656687/'}),
#  Document(page_content='Various studies have been conducted to measure financial inclusion at the country level. However, measuring financial inclusion at the household level has largely been neglected in the existing literature, particularly for emerging markets such as Vietnam. This study constructs an index of financial inclusion at the household level using the Vietnam Household Living Standard Surveys (VHLSS) in ..., ', metadata={'title': 'The determinants of financial inclusion from the households ..., ', 'source': 'https://www.semanticscholar.org/paper/The-determinants-of-financial-inclusion-from-the-in-Nguyen-Ho/ea0768a207edbb5e89e72aec7c7ced5d898f8046'}),
#  Document(page_content='Economic development is developed to raise the average standard of living in the country. Each of the below-given macro and micro economic factors influences the growth of the country. The following are economic factors affecting development. #1 - Education and Training. Education is the most important tool in the development of the country., ', metadata={'title': 'Economic Factors - What Are They, Examples, Effect On Business, ', 'source': 'https://www.wallstreetmojo.com/economic-factors/'}),
#  Document(page_content='Macroeconomic Factor: A macroeconomic factor is a factor that is pertinent to a broad economy at the regional or national level and affects a large population rather than a few select individuals ..., ', metadata={'title': 'Macroeconomic Factor: Definition, Types, Examples, and Impact, ', 'source': 'https://www.investopedia.com/terms/m/macroeconomic-factor.asp'}),
#  Document(page_content='Economic factors that affect the demand for consumer goods include employment, wages, prices/inflation, interest rates, and consumer confidence. When employment, wages, and consumer confidence are ..., ', metadata={'title': 'Which Economic Factors Most Affect the Demand for Consumer Goods?, ', 'source': 'https://www.investopedia.com/ask/answers/042815/which-economic-factors-most-affect-demand-consumer-goods.asp'}),
#  Document(page_content="These factors encompass a wide range of economic indicators that help economists and policymakers gauge the health and stability of a country's economy. Now, let's take a closer look at the different types of macroeconomic factors: 1. Economic Growth., ", metadata={'title': 'Macroeconomic Factor: Definition, Types, Examples, And Impact, ', 'source': 'https://livewell.com/finance/macroeconomic-factor-definition-types-examples-and-impact/'}),
#  Document(page_content='Real gross domestic product (GDP) increased at an annual rate of 1.4 percent in the first quarter of 2024 (table 1), according to the "third" estimate released by the Bureau of Economic Analysis. In the fourth quarter of 2023, real GDP increased 3.4 percent. The GDP estimate released today is based on more complete source data than were available for the "second" estimate issued last month., ', metadata={'title': 'Gross Domestic Product (Third Estimate), Corporate Profits (Revised ..., ', 'source': 'https://www.bea.gov/news/2024/gross-domestic-product-third-estimate-corporate-profits-revised-estimate-and-gdp-industry'}),
#  Document(page_content='Q4 2023. +3.4%. Real gross domestic product (GDP) increased at an annual rate of 1.4 percent in the first quarter of 2024, according to the "third" estimate. In the fourth quarter of 2023, real GDP increased 3.4 percent. The increase in the first quarter primarily reflected increases in consumer spending, housing investment, business investment ..., ', metadata={'title': 'Gross Domestic Product | U.S. Bureau of Economic Analysis (BEA), ', 'source': 'https://www.bea.gov/data/gdp/gross-domestic-product'}),
#  Document(page_content='This year, three countries—Bulgaria, Palau, and Russia—moved from the upper-middle-income to the high-income category: Bulgaria has been steadily approaching the high-income threshold with modest growth throughout the post-pandemic recovery period, which continued in 2023 as real GDP grew 1.8%, supported by consumption demand.; Palau also continued its post-pandemic recovery as GDP ..., ', metadata={'title': 'World Bank country classifications by income level for 2024-2025, ', 'source': 'https://blogs.worldbank.org/en/opendata/world-bank-country-classifications-by-income-level-for-2024-2025'}),
#  Document(page_content='The U.S. goods and services trade deficit increased in April 2024 according to the U.S. Bureau of Economic Analysis and the U.S. Census Bureau. The deficit increased from $68.6 billion in March (revised) to $74.6 billion in April, as imports increased more than exports. The goods deficit increased $5.9 billion in April to $99.2 billion., ', metadata={'title': 'U.S. Economy at a Glance - Bureau of Economic Analysis, ', 'source': 'https://www.bea.gov/news/glance'}),
#  Document(page_content="If a family's total income is less than the official poverty threshold for a family of that size and composition, then they are considered to be in poverty. Page Last Revised - July 6, 2022. Income inequality is the extent to which income is distributed unevenly among a population., ", metadata={'title': 'Income Inequality - Census.gov, ', 'source': 'https://www.census.gov/topics/income-poverty/income-inequality.html'}),
#  Document(page_content='The SPM child poverty rate more than doubled, from 5.2 percent in 2021 to 12.4 percent in 2022 (Figure 4 and Table B-3). ... This report presents data on income, earnings, & income inequality in the United States based on information collected in the 2023 and earlier CPS ASEC. Publication., ', metadata={'title': 'Poverty in the United States: 2022 - Census.gov, ', 'source': 'https://www.census.gov/library/publications/2023/demo/p60-280.html'}),
#  Document(page_content="This report presents data on income, earnings, & income inequality in the United States based on information collected in the 2023 and earlier CPS ASEC. ... The Census Bureau's 2020 Supplemental Poverty Measure rate was 2.3 percentage points lower than the official poverty rate of 11.4%., ", metadata={'title': 'Income in the United States: 2022 - Census.gov, ', 'source': 'https://www.census.gov/library/publications/2023/demo/p60-279.html'}),
#  Document(page_content="Research and data on Income, Wealth & Poverty from Pew Research Center Numbers, Facts and Trends Shaping Your World ... were among the Asian origin groups with the highest poverty rates in 2022. report Feb 8, 2024. Black Americans' Views on Success in the U.S. short read Dec 4, 2023. Key facts about the wealth of immigrant households during ..., ", metadata={'title': 'Income, Wealth & Poverty | Pew Research Center, ', 'source': 'https://www.pewresearch.org/topic/economy-work/income-wealth-poverty/'}),
#  Document(page_content='"There are signs that suggest labor conditions are softening, including job openings falling to more than a three-year low, temporary employment declining 25 of the past 26 months, the ..., ', metadata={'title': 'Labor Market Strength in Focus as Economy Enters Second Half of 2024, ', 'source': 'https://www.usnews.com/news/economy/articles/2024-07-01/labor-market-strength-in-focus-as-economy-enters-second-half-of-2024'}),
#  Document(page_content='Total employment is projected to increase almost 4.7 million from 2022 to 2032. 09/06/2023. Total employment is projected to grow by almost 4.7 million from 2022 to 2032. This growth is driven primarily by growth in the health care and social assistance sector. The Occupational Outlook Handbook (OOH) now features the 2022-32 projections., ', metadata={'title': 'Employment Projections - U.S. Bureau of Labor Statistics, ', 'source': 'https://www.bls.gov/emp/'}),
#  Document(page_content='U.S. job growth accelerated in February, but that likely masks underlying softening labor market conditions as the unemployment rate increased to a two-year high of 3.9%., ', metadata={'title': 'US labor market cooling; unemployment rate rises to two-year high of 3. ..., ', 'source': 'https://www.reuters.com/markets/us/us-job-growth-accelerates-february-unemployment-rate-rises-39-2024-03-08/'}),
#  Document(page_content='Experts anticipate slight increases in unemployment and layoffs in 2024. Flowers put the unemployment rate at 4.2 percent by the end of the year, up from its current 3.7 percent. "The labor ..., ', metadata={'title': '2024 US Labor Market Forecast: Hiring to Slow, Unemployment to Rise - SHRM, ', 'source': 'https://www.shrm.org/topics-tools/news/talent-acquisition/2024-us-labor-market-forecast-hiring-slow-unemployment-rise'}),
#  Document(page_content='Demographics is the study of a population based on factors such as age, race and sex, among others. Governments, corporations and non-government organizations use demographics to learn more about ..., ', metadata={'title': 'Demographics: How to Collect, Analyze, and Use Demographic Data, ', 'source': 'https://www.investopedia.com/terms/d/demographics.asp'}),
#  Document(page_content="Examples of demographics can include factors such as the race, sex and age of a population that is being studied. The statistical information on the population's socioeconomic conditions is known as demographic data. Demographic data can contain specific information about the characteristics of a given population, such as the following examples:, ", metadata={'title': 'What Are Demographics? (Definition, Examples and Uses), ', 'source': 'https://www.indeed.com/career-advice/career-development/demographics-definition'}),
#  Document(page_content='demography, statistical study of human populations, especially with reference to size and density, distribution, and vital statistics (births, marriages, deaths, etc.). Contemporary demographic concerns include the "population explosion," the interplay between population and economic development, the effects of birth control, urban ..., ', metadata={'title': 'Demography | Population Trends, Migration & Age Structure, ', 'source': 'https://www.britannica.com/topic/demography'}),
#  Document(page_content='The 2020 Census Demographic Profile is very similar to the 2010 Census Demographic Profile. Both are available down to the tract level. The content is the same except for a few statistics related to household size that are planned for inclusion in the Supplemental Demographic and Housing Characteristics File (S-DHC) instead, which you can learn ..., ', metadata={'title': '2020 Census Demographic Profile, ', 'source': 'https://www.census.gov/data/tables/2023/dec/2020-census-demographic-profile.html'}),
#  Document(page_content='Population density and its variation are topics of continuous interest in urban, environmental, and human geography research. The accurate evaluation of the spatial-temporal distribution and ..., ', metadata={'title': 'Assessing spatiotemporal population density dynamics from 2000 ... - Nature, ', 'source': 'https://www.nature.com/articles/s41598-024-63311-5'}),
#  Document(page_content='Share of the total population living in urban areas, given as estimates by HYDE until 2023 and UN projections through 2050, using the median fertility scenario for future urbanization trends. ... Population is represented by maps of total, urban, rural population and population density as well as built-up area. The period covered is 10 000 BCE ..., ', metadata={'title': 'Share of the population living in urban areas - Our World in Data, ', 'source': 'https://ourworldindata.org/grapher/urban-population-share-2050'}),
#  Document(page_content='grids of population density cells to define three types of cells: 1) cities are defined as settlements of at least 50,000 inhabitants in a high-density cluster of grid cells (greater than 1,500 inhabitants per sq. km); 2) towns and semi-dense areas are defined as urban clusters outside cities with at least 5,000 inhabitants in contiguous ..., ', metadata={'title': 'Rethinking the country-level percentage of population residing in urban ..., ', 'source': 'https://www.cell.com/iscience/fulltext/S2589-0042(24)01350-6'}),
#  Document(page_content='For degree of urbanization, we categorize the cities into four classes—urban, suburban, periurban and rural—based on location, housing density, population and commute time., ', metadata={'title': 'Depopulation and associated challenges for US cities by 2100, ', 'source': 'https://www.nature.com/articles/s44284-023-00011-7'}),
#  Document(page_content='The PISA 2022 Volume IV financial literacy assessment, which measured the financial skills of 15-year-olds in 14 OECD and 6 partner countries and economies, shows that many students engage in basic financial activities from a young age. On average, more than eight in ten students have bought something online during the last 12 months and 66% of ..., ', metadata={'title': 'Action needed to address gaps in financial literacy among students, ', 'source': 'https://www.oecd.org/en/about/news/press-releases/2024/06/Action-needed-to-address-gaps-in-financial-literacy-among-students.html'}),
#  Document(page_content='The same can be found across race and ethnicity groups. Black and Hispanic respondents had lower actual financial literacy levels than Whites and Asians; yet, their self-rating of financial literacy was very similar to that of Whites and Asians. The average self-rating was 5.1, 5, 4.9, and 5.1 among Whites, Blacks, Hispanics, and Asians., ', metadata={'title': 'Financial literacy and financial well-being: Evidence from the US, ', 'source': 'https://www.cambridge.org/core/journals/journal-of-financial-literacy-and-wellbeing/article/financial-literacy-and-financial-wellbeing-evidence-from-the-us/318307008828D2D7932C13E04B90DD88'}),
#  Document(page_content='In the U.S., the racial wealth gap is stark. According to the Brookings Institute, the median wealth for a white household is $188,200, nearly eight times more than the average black household ..., ', metadata={'title': "How racial disparities in financial education affect America's wealth ..., ", 'source': 'https://www.pbs.org/newshour/show/how-racial-disparities-in-financial-education-affect-americas-wealth-gap'}),
#  Document(page_content='The percentage of US adults demonstrating a very low level of financial literacy increased from 20% in 2017 to 25% in 2023. TIAA\'s yearly released financial literacy index showed that the share of US adults exhibiting "very low" levels of financial literacy (ie, they correctly answered seven or fewer of the 28 index questions) has been on an upward trend in recent years., ', metadata={'title': 'US Financial Literacy Statistics 2024: Key Demographics & Cost - Moneyzine, ', 'source': 'https://moneyzine.com/personal-finance/financial-literacy-statistics/'}),
#  Document(page_content="The statistics are telling - from the gender disparity in venture capital funding to the lack of formal financial access for women globally. Digital financial services can serve as an on-ramp for low-income women to adopt and use a large suite of formal financial products and services, expanding women's choices and their financial and ..., ", metadata={'title': 'Bridging the Gender Gap: How Fintechs Drive Financial Inclusion, ', 'source': 'https://www.womensworldbanking.org/insights/bridging-the-gender-gap-how-fintechs-drive-financial-inclusion/'}),
#  Document(page_content='This study investigates the determinants of gender disparities in financial inclusion in Pakistan using Global Findex 2021 survey data. We aim to quantify gender gaps in financial access and use ..., ', metadata={'title': 'Determinants of financial inclusion gaps in Pakistan and ... - Nature, ', 'source': 'https://www.nature.com/articles/s41598-024-63445-6'}),
#  Document(page_content="Financial institutions inadvertently perpetuate gender disparities by offering generic financial products that inadequately address the unique needs of women. Additionally, regulatory hurdles and discriminatory laws, impede women's access to financial services. Globally, on average, women enjoy only 77 percent of the legal rights that men do., ", metadata={'title': 'Empowering women through digital financial inclusion - World Bank Blogs, ', 'source': 'https://blogs.worldbank.org/en/psd/empowering-women-through-digital-financial-inclusion'}),
#  Document(page_content='Consequently, Kenya has become a leader in financial inclusion in sub-Saharan Africa. A decade ago, only 26.7% of the adult population in Kenya had access to formal financial services. By 2016, about 9 years after the launch of M-Pesa, the number rose to 75%. The number rose to 85% by 2021 (Njoroge et al., 2021 )., ', metadata={'title': 'Fintech and Financial Inclusion: Closing the Gender Gap, ', 'source': 'https://link.springer.com/chapter/10.1007/978-3-031-53337-2_7'}),
#  Document(page_content='Some institutional factors can be represented in models through technology cost and deployment, such as electricity market rules. Others are deeply uncertain and complex, such as social norms, which makes quantitative modeling quite challenging. In essence, the right model choice depends on what institutional factor one hopes to capture, and ..., ', metadata={'title': 'Research Shows Institutional Factors are Key in Improving ..., ', 'source': 'https://cpree.princeton.edu/news/2024/research-shows-institutional-factors-are-key-improving-sustainability-models'}),
#  Document(page_content='Therefore, it can be asserted that various studies, including those mentioned in this section, have consistently demonstrated the positive and significant impact of various factors, such as institutional quality, democracy, gross domestic product, improved health expanditure, and higher education levels, in enhancing life expectancy and ..., ', metadata={'title': 'What is the role of institutional quality in health outcomes? A panel ..., ', 'source': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10560016/'}),
#  Document(page_content='Efficient environmental resource management is a major problem for countries participating in the Belt and Road Initiative (BRI) in sustainable development (SD). This article determines the effects of BRI policy and institutional factors (corruption control, rule of law, and political stability) on sustainable development in 103 BRI countries between 2007 and 2019. We use across high-income ..., ', metadata={'title': 'How do institutional factors affect sustainable development? A ..., ', 'source': 'https://link.springer.com/article/10.1007/s10644-024-09580-6'}),
#  Document(page_content='Yet, as critics of institutional analysis (Alvesson & Spicer, 2019) rightly maintain, institutional explanations may be overused, and other factors such as power, status, demography, resource dependencies, cognition, emotions, identity, and meaning have effects that are not reducible to institutions. While it is helpful to examine the ..., ', metadata={'title': 'Institutions and Their Social Construction: A Cross-Level Perspective, ', 'source': 'https://journals.sagepub.com/doi/full/10.1177/26317877231194368'}),
#  Document(page_content='The decision is expected to prompt a rush of litigation challenging regulations across the entire federal government, from food safety to the environment. By Coral Davenport, Christina Jewett ..., ', metadata={'title': 'What the Chevron Ruling Means for the Federal Government - The New York ..., ', 'source': 'https://www.nytimes.com/2024/06/28/us/politics/chevron-deference-decision-meaning.html'}),
#  Document(page_content='Roughly eight-in-ten Democrats (82%) say government regulation is necessary to protect the public interest. Among other demographic differences: White adults (45%) are the most likely to say government regulation does more harm than good, while smaller shares of Hispanic (32%), Asian (29%) and Black (27%) adults say the same., ', metadata={'title': "1. Government's scope, efficiency and role in regulating business, ", 'source': 'https://www.pewresearch.org/politics/2024/06/24/governments-scope-efficiency-and-role-in-regulating-business/'}),
#  Document(page_content="OMB's Grants Management Home Page - Government-wide grants management policies and guidelines through circulars and common rules. 45 CFR Part 75 - Part 75—Uniform Administrative Requirements, Cost Principles, and Audit Requirements for HHS Awards. Grants Oversight and New Efficiency Act (PL114-117) Grants Fraud Alert., ", metadata={'title': 'Grants Policies & Regulations | HHS.gov, ', 'source': 'https://www.hhs.gov/grants-contracts/grants/grants-policies-regulations/index.html'}),
#  Document(page_content='Regulations Supporting Businesses. Hundreds of assistance programs from the government—in the form of money, information, and services—are available to businesses and entrepreneurs. The Small ..., ', metadata={'title': 'Government Regulations: Do They Help Businesses? - Investopedia, ', 'source': 'https://www.investopedia.com/articles/economics/11/government-regulations.asp'}),
#  Document(page_content="The benefits of a CBT Review for central banks are four-fold: First, it helps improve the central bank's transparency practices and the communication framework, leading to policy credibility. Second, it will strengthen relations with stakeholders such as parliament, market participants, and the public at large., ", metadata={'title': "Central Bank Independence: Why It's Needed and How to Protect It - IMF, ", 'source': 'https://www.imf.org/en/News/Articles/2024/06/17/sp061424-central-bank-independence'}),
#  Document(page_content='November 20, 2023. Central bank digital currencies can improve payment systems as well as financial inclusion—if they are appropriately designed. If not, they could pose risks. While not all countries may see an immediate case to deploy a CBDC, many countries are exploring CBDCs so they will have the option to introduce one in the future if ..., ', metadata={'title': 'Central Bank Digital Currency Development Enters the Next Phase - IMF, ', 'source': 'https://www.imf.org/en/Blogs/Articles/2023/11/20/central-bank-digital-currency-development-enters-the-next-phase'}),
#  Document(page_content='Recourse to central bank financing had started to drift to levels seen outside the region between 2000 and the global financial crisis—from 4 to 2 percent of GDP. But since then, borrowing from central banks has been trending upwards, and jumped a notch with the onset of the COVID pandemic bringing the median level of borrowing back to the 4 ..., ', metadata={'title': 'The Evolving Role of Central Banks in Africa - IMF, ', 'source': 'https://www.imf.org/en/News/Articles/2024/06/07/sp060724-central-banks-in-africa-abebe-aemro-selassie'}),
#  Document(page_content="Zhou , the former People's Bank of China (PBoC) Governor, emphasized central banks' multiple responsibilities—including financial sector development and stability—in transition and developing economies. He noted, 'monetary policy will undoubtedly be affected by balance of international payments and capital flows'., ", metadata={'title': 'Inflation and Development: Central Bank Stabilization Policies ..., ', 'source': 'https://link.springer.com/article/10.1057/s41301-023-00359-2'}),
#  Document(page_content='international legal frameworks, ile intellectual property and corporate law review, 2 (1) of 2023, PG. 37-45 , APIS - 3920-0008 | ISSN - 2583 - 6153. ABSTRACT, ', metadata={'title': 'Protection of Intellectual Property Rights: an Examination of ..., ', 'source': 'https://www.researchgate.net/publication/376032246_PROTECTION_OF_INTELLECTUAL_PROPERTY_RIGHTS_AN_EXAMINATION_OF_INTERNATIONAL_LEGAL_FRAMEWORKS'}),
#  Document(page_content='Ownership is a legal concept that grants individuals the bundle of property rights we discussed above. By contrast, possession refers to control over property and the right to use or occupy it. 5. Individuals may own property without possessing it or vice versa. For instance, a renter takes temporary possession of an apartment, but the landlord ..., ', metadata={'title': 'Understanding Property Rights in Law| Pitt MSL Online, ', 'source': 'https://online.law.pitt.edu/blog/an-overview-of-property-rights-in-law'}),
#  Document(page_content="Foreign Direct Investment, the rule of law, and robust IP rights protection are interconnected and vital for attracting FDI to the US. The US legal system's stability, transparency, and protection of intellectual property assets instill confidence in foreign investors. By upholding the rule of law and continually improving IP rights ..., ", metadata={'title': 'The Rule of Law and IP Rights Protection: Key Factors in Attracting FDI ..., ', 'source': 'https://researchfdi.com/resources/articles/the-rule-of-law-and-ip-rights-protection-key-factors-in-attracting-fdi-to-the-us/'}),
#  Document(page_content='Property rights refer to the theoretical and legal ownership of specific property by individuals and the ability to determine how such property is used. In many countries, including the United ..., ', metadata={'title': 'What Are Property Rights and Why Do They Matter? - Investopedia, ', 'source': 'https://www.investopedia.com/terms/p/property_rights.asp'}),
#  Document(page_content="To begin, let us define technological factors as external elements that influence a company's operations and strategies. Examples of technological factors include advancements in communication, automation, data analytics, and e-commerce. These factors can have both positive and negative impacts on businesses, depending on how they are leveraged ..., ", metadata={'title': 'A Comprehensive Look at Technological Factors, ', 'source': 'https://www.businessanalysisinsights.com/pestle-analysis-technological-factors'}),
#  Document(page_content="A PESTLE analysis examines external market factors - including Political, Economic, Social, Technological, Legal, and Environmental - and market trends that might impact your organization's direction, performance, and position in the marketplace. Used in tandem with a SWOT analysis, it helps your organization examine external factors that ..., ", metadata={'title': 'What is a PESTLE Analysis? A Complete PESTLE Analysis Guide - OnStrategy, ', 'source': 'https://onstrategyhq.com/resources/pestle-analysis/'}),
#  Document(page_content="The technological environment of business encompasses external elements within technology that impact business operations. Changes in technology can reshape how a company operates, prompting significant shifts in the organization's strategies. It resides in the company's external realm, is tied to technological developments, and holds the ..., ", metadata={'title': 'What is Technological Environment? Factors, Examples, & Strategy, ', 'source': 'https://mbanote.org/technological-environment/'}),
#  Document(page_content='4. Identify the technological factors. Although identifying technological factors is particularly important in tech industries, these considerations affect every industry in some way. ..., ', metadata={'title': 'What Is a PEST Analysis? - Business News Daily, ', 'source': 'https://www.businessnewsdaily.com/5512-pest-analysis-definition-examples-template.html'}),
#  Document(page_content='Premium Statistic Latin America and the Caribbean: mobile internet penetration 2022, by country ... Number of mobile phone internet users in India from 2010 to 2023, with estimates until 2050 (in ..., ', metadata={'title': 'Mobile internet usage worldwide - Statistics & Facts | Statista, ', 'source': 'https://www.statista.com/topics/779/mobile-internet/'}),
#  Document(page_content='Internet users approaching supermajority. The latest country-level data indicate that global internet penetration now sits at 66.2 percent.. This means that we\'re only a few basis points short of internet users reaching "supermajority" status, when twice as many people will be using the internet as not.. Based on current growth rates, we expect internet adoption to reach this important ..., ', metadata={'title': 'Internet use in 2024 — DataReportal - Global Digital Insights, ', 'source': 'https://datareportal.com/reports/digital-2024-deep-dive-the-state-of-internet-adoption'}),
#  Document(page_content='Mobile phone ownership over time. The vast majority of Americans - 97% - now own a cellphone of some kind. Nine-in-ten own a smartphone, up from just 35% in Pew Research Center\'s first survey of smartphone ownership conducted in 2011. ... Today, 15% of U.S. adults are "smartphone-only" internet users - meaning they own a smartphone ..., ', metadata={'title': 'Mobile Fact Sheet - Pew Research Center, ', 'source': 'https://www.pewresearch.org/internet/fact-sheet/mobile/'}),
#  Document(page_content='In a far cry from the early 2000s, most U.S. adults today say they use the internet (95%), have a smartphone (90%) or subscribe to high-speed internet at home (80%), according to a Pew Research Center survey conducted May 19 to Sept. 5, 2023. Though adoption of these technologies has surged over the past two decades, there are notable ..., ', metadata={'title': "Americans' Use of Mobile Technology and Home Broadband, ", 'source': 'https://www.pewresearch.org/internet/2024/01/31/americans-use-of-mobile-technology-and-home-broadband/'}),
#  Document(page_content='VC funding was hit hard globally and across sectors, dropping to $459.6 billion in 2022 from $683.1 billion in 2021. Fintech funding faced a 40 percent year-over-year funding decline, down from $92 billion to $55 billion. Yet, when analyzed over a five-year period, fintech funding as a proportion of total VC funding remained fairly stable at 12 ..., ', metadata={'title': 'The future of fintech growth | McKinsey, ', 'source': 'https://www.mckinsey.com/industries/financial-services/our-insights/fintechs-a-new-paradigm-of-growth'}),
#  Document(page_content='Fintech, the application of digital technology to financial services, is reshaping the future of finance- a process that the COVID-19 pandemic has accelerated. The ongoing digitization of financial services and money creates opportunities to build more inclusive and efficient financial services and promote economic development., ', metadata={'title': 'Fintech and the Future of Finance - World Bank Group, ', 'source': 'https://www.worldbank.org/en/publication/fintech-and-the-future-of-finance'}),
#  Document(page_content="But innovation doesn't happen in silos. Fintechs, for example, have been transformational for the financial services industry, from democratizing finance to establishing digital currencies that revolutionized the way that we think of money. As fintechs race to keep up with the needs of their customers and co-create with larger financial ..., ", metadata={'title': 'How fintech innovation is driving digital transformation for ... - IBM, ', 'source': 'https://www.ibm.com/blog/how-fintech-innovation-is-driving-digital-transformation-for-communities/'}),
#  Document(page_content='"It is highly encouraging to see fintech performance remain strong after the COVID-19 pandemic, with average global customer growth rates above 50% from 2021-2022; however, identified headwinds such as a difficult macroeconomic climate and decreased fintech funding cannot be ignored," said Drew Propson, Head, Technology and Innovation in Financial Services, World Economic Forum., ', metadata={'title': 'New Research Reveals Resilient and Growing Fintech Industry, Driven by ..., ', 'source': 'https://www.weforum.org/press/2024/01/wef24-new-research-reveals-resilient-and-growing-fintech-industry-driven-by-consumer-demand/'}),
#  Document(page_content='The number of global internet users and the percentage of internet penetration continued to grow from 2021 to 2022 at 7% and 6% respectively. While this growth indicates that progress has been ..., ', metadata={'title': 'Fixing the global digital divide and digital access gap, ', 'source': 'https://www.brookings.edu/articles/fixing-the-global-digital-divide-and-digital-access-gap/'}),
#  Document(page_content="IT infrastructure is the group of technologies and components that make up an organization's IT environment, which powers computing, networking and digital operations. Gartner defines IT ..., ", metadata={'title': "What Is IT Infrastructure? Definition & Why It's Important, ", 'source': 'https://www.forbes.com/advisor/business/software/what-is-it-infrastructure/'}),
#  Document(page_content='Sustainable digital infrastructure is a necessity in our increasingly interconnected world. However, the existing funding gap poses challenges to equitable access and further development. Approximately 4.5 billion people lack access to the internet worldwide. In Africa, only 17.8% of people have home internet access and only 10.7% have computers., ', metadata={'title': 'The Key to Building a Sustainable Future: Inclusive Digital Infrastructure, ', 'source': 'https://www.thirdway.earth/insightsadmin/the-key-to-building-a-sustainable-future-inclusive-digital-infrastructure'}),
#  Document(page_content='Infrastructure as a Catalyst for Connectivity. Unlocking Digital Access through Strategic Infrastructure Development. At the core of closing the digital divide lies the strategic development of ..., ', metadata={'title': 'Digital Divide and Infrastructure: Bridging the Connectivity Gap - LinkedIn, ', 'source': 'https://www.linkedin.com/pulse/bridging-digital-divide-role-infrastructure-enhancing-aneesh-goly-w6rve'}),
#  Document(page_content="The study started as an examination of Hofstede's colleagues across IBM's offices around the world. At the time, he only included four dimensions in his theory, which he published in 1980: Power Distance, Individualism versus Collectivism, Masculinity versus Femininity, and Uncertainty Avoidance. Then, with the help of Michael Harris Bond ..., ", metadata={'title': "Hofstede's Six Cultural Dimensions—and Why They Matter - Verywell Mind, ", 'source': 'https://www.verywellmind.com/hofstedes-cultural-dimensions-8583990'}),
#  Document(page_content='Cultural factors pertain to the beliefs, values, and practices that a group of people share. This can encompass aspects such as language, religion, customs, and traditions. These elements get passed down from generation to generation and contribute to defining a society. On the other hand, social factors are elements that affect an individual ..., ', metadata={'title': '101 Cultural Factors Examples (2024) - Helpful Professor, ', 'source': 'https://helpfulprofessor.com/cultural-factors-examples/'}),
#  Document(page_content="Social factors often involve the immediate and tangible aspects of a person's life, such as their social networks and community roles. Cultural factors, in contrast, include the collective customs, languages, and artistic expressions that define a group's identity. 9. Social factors can directly affect a person's opportunities and life choices ..., ", metadata={'title': "Social Factors vs. Cultural Factors: What's the Difference?, ", 'source': 'https://www.difference.wiki/social-factors-vs-cultural-factors/'}),
#  Document(page_content="Social cultural factors influence people's feelings, behaviors, attitudes, values, beliefs and interactions. These factors shape social development, economic development and cultural change., ", metadata={'title': 'Sociocultural Factors | Definition, Development & Examples, ', 'source': 'https://study.com/academy/lesson/sociocultural-factors-impacting-economic-development.html'}),
#  Document(page_content='In general, here are the steps you will take to open a trust bank account. Choose a financial institution or brokerage. Find or request an application for a trust account. Provide required ..., ', metadata={'title': 'Best Banks For Trust Accounts In 2024 - Forbes Advisor, ', 'source': 'https://www.forbes.com/advisor/banking/best-banks-for-trust-accounts/'}),
#  Document(page_content='Account In Trust: An account in trust is a general term used to define any type of financial account that is opened by an individual and managed by a designated trustee for the benefit of a third ..., ', metadata={'title': 'Account in Trust: Definition, Types, Benefits, How To Set One Up, ', 'source': 'https://www.investopedia.com/terms/a/account-in-trust.asp'}),
#  Document(page_content='4. Choose a bank or financial institution. Be sure to ask about fees, minimum balances and required opening balances before making your decision. 5. Finalize documentation. Give the financial ..., ', metadata={'title': 'How to Open a Trust Account - NerdWallet, ', 'source': 'https://www.nerdwallet.com/article/investing/estate-planning/how-to-open-trust-account'}),
#  Document(page_content='Consistency And Reliability. Maintaining consistent communication, service quality and adherence to ethical standards ensures trust evolves into a lasting bond. In conclusion, trust is the ..., ', metadata={'title': 'Forging Enduring Trust: A Strategic Toolbox For Financial Institutions, ', 'source': 'https://www.forbes.com/sites/forbesbusinesscouncil/2024/04/03/forging-enduring-trust-a-strategic-toolbox-for-financial-institutions/'}),
#  Document(page_content="Individuals' attitudes toward money are affected, and finance determines individual behavior regarding savings, borrowing, and risk-taking (Agarwalla et al. 2013). Savings history is essential for reaping the full benefits of the intervention, which is consistent with the literature on savings, which emphasizes the importance of habit formation ..., ", metadata={'title': 'Impact of financial literacy on savings behavior: the ... - Springer, ', 'source': 'https://link.springer.com/article/10.1057/s41264-023-00265-1'}),
#  Document(page_content="To be more precise, Jorgensen and Savla found that the extent to which young adults (aged 18-29) believed their parents influenced their attitude towards money had a direct impact on that attitude, and that attitude in turn had an indirect impact on the young adults' actual behaviour concerning money. When taken together, these pieces of ..., ", metadata={'title': 'Financial Socialisation and Personal Financial Management ... - Springer, ', 'source': 'https://link.springer.com/chapter/10.1007/978-981-99-0197-5_21'}),
#  Document(page_content="This comprehensive exploration delves into the psychological underpinnings of financial behavior, highlighting how one's mindset and emotional states crucially influence financial decision-making. The piece aims to illuminate pathways towards a healthier financial self, interweaving psychological theories and empirical research. Additionally, it underscores the role of practical tools like a ..., ", metadata={'title': 'The Psychology of Money: How Your Mindset Shapes Your Financial Health, ', 'source': 'https://psychtimes.com/psychology/the-psychology-of-money-how-your-mindset-shapes-your-financial-health/'}),
#  Document(page_content='Financial literacy can be defined as knowledge of the general concepts of personal finance—such as saving, borrowing, and budgeting—and the specific tools necessary to effectively manage money. To achieve a healthy financial lifestyle, individuals must demonstrate their knowledge and ability in different aspects of finance., ', metadata={'title': "Leading Generation Z's Financial Literacy Through Financial Education ..., ", 'source': 'https://journals.sagepub.com/doi/10.1177/21582440231188308'}),
#  Document(page_content='Financial websites (including Investopedia) are another powerful and convenient resource for financial education. Find a Good Book For anyone trying to build their financial literacy , one place ..., ', metadata={'title': 'Best Resources for Improving Financial Literacy - Investopedia, ', 'source': 'https://www.investopedia.com/best-resources-for-improving-financial-literacy-5091689'}),
#  Document(page_content='Accessing Formal Education And Awareness Programs. The foundation of financial literacy often begins with structured education. Schools, colleges, and universities offer basic money management ..., ', metadata={'title': 'Why Financial Literacy Is Important And How You Can Improve Yours - Forbes, ', 'source': 'https://www.forbes.com/sites/truetamplin/2023/09/21/financial-literacy--meaning-components-benefits--strategies/'}),
#  Document(page_content="Free Resources For Teachers. InCharge is proud to offer free financial literacy resources to teachers, K-12, college and adult. These are designed for individual study as well as in-person workshop experiences. These resources are free for downloading, printing and reproducing. Teacher's guides included., ", metadata={'title': 'Financial Literacy: Free Personal Finance Education Materials, ', 'source': 'https://www.incharge.org/financial-literacy/'}),
#  Document(page_content="Financial literacy is a person's understanding of money topics. Someone who's financially literate would be able to set a budget, manage a bank account, and achieve a good credit score. Financial literacy could also include more complex skills like managing debt, buying insurance, investing, and retirement planning., ", metadata={'title': 'Financial literacy: What is it and why is it so important? | Fidelity, ', 'source': 'https://www.fidelity.com/learning-center/smart-money/financial-literacy'})]

# %%
def run_main(context, question):
    final_rag_chain = (
        {"context": itemgetter("context"),
         "question": itemgetter("question")}
        | prompt_2
        | model
        | StrOutputParser()
    )
    return final_rag_chain.invoke({'context': context, 'question': question})

res = run_main(format_docs(context), question)
# question = "What are the determinants of financial inclusion in Vietnam?"
# final_rag_chain.invoke({"question": question})

# %%
res
# Out:
# 'Based on the provided article snippets, the key determinants of financial inclusion in Vietnam are:\n\n* **Total income per household:** Higher income households are more likely to be financially included. This is consistent with findings from other studies that highlight income as a major factor in financial inclusion.\n* **Education level:** Individuals with higher levels of education are more likely to be financially included.  The article specifically mentions that "less educated" individuals face barriers to financial inclusion.\n* **Labor force participation:** Individuals who are part of the workforce are more likely to be financially included compared to those out of the workforce.\n* **Age:** Age has a significant impact on financial inclusion, though the relationship is not simply linear. The article mentions both "old people" facing barriers and "young age" being associated with lower financial inclusion in other studies.\n* **Gender:** While the article highlights gender disparities in financial inclusion globally, in the specific context of Vietnam, the findings suggest a less pronounced gap. However, being female is still associated with a slightly lower level of financial inclusion.\n\nThe article also points to other potential determinants and barriers to financial inclusion in Vietnam, though it doesn\'t explicitly confirm their significance within the Vietnamese context:\n\n* **Distance to financial institutions:** This is a common barrier to financial inclusion, particularly in rural areas.\n* **Cost of financial services:** High costs can deter individuals from accessing financial products and services.\n* **Lack of necessary documentation:** This can be a barrier for individuals who lack formal identification or proof of income.\n* **Lack of trust in financial institutions:**  Trust is crucial for individuals to feel comfortable using financial services.\n* **Lack of awareness and financial literacy:**  Understanding how to use financial products and services effectively is essential for financial inclusion.\n\nThis study primarily focuses on individual and household characteristics as determinants of financial inclusion in Vietnam. Further research might be needed to explore the influence of broader factors like government policies, financial literacy initiatives, and the development of financial infrastructure. \n'
